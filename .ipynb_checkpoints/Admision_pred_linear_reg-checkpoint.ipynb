# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\Assignment\Admission_Prediction.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1      337.0        118.0                4.0  4.5  4.5  9.65
# 1           2      324.0        107.0                4.0  4.0  4.5  8.87
# 2           3        NaN        104.0                3.0  3.0  3.5  8.00
# 3           4      322.0        110.0                3.0  3.5  2.5  8.67
# 4           5      314.0        103.0                2.0  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df.shape
# Out:
# (500, 9)

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  485.000000   490.000000         485.000000  500.000000
# mean   250.500000  316.558763   107.187755           3.121649    3.374000
# std    144.481833   11.274704     6.112899           1.146160    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR        CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# ...

# %%
df.isnull().sum()
# Out:
# Serial No.            0
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
# GRE Score            15
# TOEFL Score          10
# University Rating    15

df['GRE Score'] = df['GRE Score'].fillna(df['GRE Score'].mean())

# %%
df['TOEFL Score'] = df['TOEFL Score'].fillna(df['TOEFL Score'].mean())

# %%
df['University Rating'] = df['University Rating'].fillna(df['University Rating'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    float64
#  2   TOEFL Score        500 non-null    float64
#  3   University Rating  500 non-null    float64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(7), int64(2)
# memory usage: 35.3 KB

# %%
df.drop('Serial No.',axis=1,inplace=True)

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,25),facecolor='White')
plotnum = 1
for columns in df:
    if plotnum < 16:
        plt.subplot(4,4,plotnum)
        sns.distplot(df[columns])
        plt.xlabel(columns,fontsize=20)
    plotnum+=1

# %%
x = df.drop('Chance of Admit',axis=1)

# %%
y = df['Chance of Admit']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
model = LinearRegression()

# %%
LR = model.fit(x_train,y_train)

# %%
coe = LR.coef_

# %%
LR.intercept_
# Out:
# -1.3902452159046126

# %%
coeff = pd.DataFrame(data = coe,index=x_train.columns,columns=['Coefficient of x'])

# %%
coeff
# Out:
#                    Coefficient of x
# GRE Score                  0.002036
# TOEFL Score                0.003467
# University Rating          0.002687
# SOP                        0.001903
# LOR                        0.014638
# CGPA                       0.118817
# Research                   0.022931

# %%
y_pred = LR.predict(x_test)

# %%
y_pred
# Out:
# array([0.91806624, 0.79846755, 0.56992936, 0.72244872, 0.81873131,
#        0.86198782, 0.48003713, 0.68764373, 0.82687709, 0.80763002,
#        0.72235623, 0.73057956, 0.6514197 , 0.93439964, 0.82792397,
#        0.51305726, 0.8354314 , 0.59727112, 0.53812609, 0.56935953,
#        0.6626412 , 0.55339962, 0.72134446, 0.79173627, 0.78060656,
#        0.60730328, 0.95175927, 0.84674266, 0.62793475, 0.74458953,
#        0.55838643, 0.73544944, 0.54904753, 0.86307096, 0.65338128,
#        0.73638073, 0.55639278, 0.92791197, 0.6442272 , 0.71191347,
#        0.96750671, 0.57316771, 0.6898729 , 0.85790965, 0.94048501,
#        0.58292994, 0.95976788, 0.83695472, 0.7940342 , 0.92764192,
#        0.89011291, 0.59963812, 0.70735476, 0.52069933, 0.95347903,
#        0.5910266 , 0.95914019, 0.74382313, 0.66855684, 0.50101703,
#        0.6349243 , 0.67894109, 0.60213883, 0.59376446, 0.4401514 ,
#        0.58842379, 0.86843509, 0.8970783 , 0.65915358, 0.70832751,
# ...

# %%
y_test
# Out:
# 361    0.93
# 73     0.84
# 374    0.39
# 155    0.77
# 104    0.74
#        ...
# 266    0.72
# 23     0.95
# 222    0.76
# 261    0.71
# 426    0.71
# Name: Chance of Admit, Length: 150, dtype: float64

# %%
import numpy as np
def co():
    coeff = pd.DataFrame(data = coe,index=x_train.columns,columns=['Coefficient of x'])
    return coeff



def ad_r2(x,y):
    r2= LR.score(x,y)
    n=x.shape[0]
    p=x.shape[1]
    adjr2=1-(1-r2)*(n-1)/(n-p-1)
    return adjr2


def error():
    MAE=metrics.mean_absolute_error(y_test,y_pred)
    MAPE=metrics.mean_absolute_percentage_error(y_test,y_pred)
    MSE=metrics.mean_squared_error(y_test,y_pred)
    RMSE=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
    ACCURACY=(100-metrics.mean_absolute_percentage_error(y_test,y_pred)*100)
    
    r2_train = metrics.r2_score(y_train,LR.predict(x_train)) 
    r2_test = metrics.r2_score(y_test,y_pred) 
    
    adjr2_training=ad_r2(x_train,y_train)
    adjr2_testing=ad_r2(x_test,y_test)
    
        
    
    error_column = ['r2_train','r2_test','adjr2_training','adjr2_testing','MAE','MAPE','MSE','RMSE','ACCURACY']
    data = [r2_train,r2_test,adjr2_training,adjr2_testing,MAE,MAPE,MSE,RMSE,ACCURACY]
    error=pd.DataFrame(data=data,index=error_column,columns=['Values'])
    return error



error()
co()
# Out:
#                    Coefficient of x
# GRE Score                  0.002036
# TOEFL Score                0.003467
# University Rating          0.002687
# SOP                        0.001903
# LOR                        0.014638
# CGPA                       0.118817
# Research                   0.022931

# %%
def co():
    coeff = pd.DataFrame(data = coe,index=x_train.columns,columns=['Coefficient of x'])
    return coeff
co()
# Out:
#                    Coefficient of x
# GRE Score                  0.002036
# TOEFL Score                0.003467
# University Rating          0.002687
# SOP                        0.001903
# LOR                        0.014638
# CGPA                       0.118817
# Research                   0.022931

# %%
def ad_r2(x,y):
    r2= LR.score(x,y)
    n=x.shape[0]
    p=x.shape[1]
    adjr2=1-(1-r2)*(n-1)/(n-p-1)
    return adjr2
ad_r2(x_train,y_train)
# Out:
# 0.8127855020224761

# %%
def ad_r2(x,y):
    r2= LR.score(x,y)
    n=x.shape[0]
    p=x.shape[1]
    adjr2=1-(1-r2)*(n-1)/(n-p-1)
    return adjr2
ad_r2(x_test,y_test)
# Out:
# 0.8170355661492992
